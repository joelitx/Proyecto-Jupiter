# %% [markdown]
# <a href="https://colab.research.google.com/github/joelitx/Proyecto-Jupiter/blob/main/Lotes_Joel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3cd5318-544d-44af-9277-6fe237cc495e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3cd5318-544d-44af-9277-6fe237cc495e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta = "/content/drive/MyDrive/lotes.json"

import json
with open(ruta, "r", encoding="utf-8") as f:
    datos = json.load(f)

print(type(datos))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-11-53907339.py in <cell line: 0>()
#       2
#       3 import json
# ----> 4 with open(ruta, "r", encoding="utf-8") as f:
#       5     datos = json.load(f)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/lotes.json'

# %%
ruta = "/content/drive/MyDrive/Colab Notebooks/lotes.json"

import json
with open(ruta, "r", encoding="utf-8") as f:
    data = json.load(f)

print(type(data))
# Out:
# <class 'dict'>

# %%
print(data.keys())
# Out:
# dict_keys(['Apple 1.png', 'Apple 10.png', 'Apple 100.png', 'Apple 101.png', 'Apple 102.png', 'Apple 103.png', 'Apple 104.png', 'Apple 105.png', 'Apple 106.png', 'Apple 107.png', 'Apple 108.png', 'Apple 109.png', 'Apple 11.png', 'Apple 110.png', 'Apple 111.png', 'Apple 112.png', 'Apple 113.png', 'Apple 114.png', 'Apple 115.png', 'Apple 116.png', 'Apple 117.png', 'Apple 118.png', 'Apple 119.png', 'Apple 12.png', 'Apple 120.png', 'Apple 121.png', 'Apple 122.png', 'Apple 123.png', 'Apple 124.png', 'Apple 125.png', 'Apple 126.png', 'Apple 127.png', 'Apple 128.png', 'Apple 129.png', 'Apple 13.png', 'Apple 130.png', 'Apple 131.png', 'Apple 132.png', 'Apple 133.png', 'Apple 134.png', 'Apple 135.png', 'Apple 136.png', 'Apple 137.png', 'Apple 138.png', 'Apple 139.png', 'Apple 14.png', 'Apple 140.png', 'Apple 141.png', 'Apple 142.png', 'Apple 143.png', 'Apple 144.png', 'Apple 145.png', 'Apple 146.png', 'Apple 147.png', 'Apple 148.png', 'Apple 149.png', 'Apple 15.png', 'Apple 150.png', 'Apple 15
# ...

# %%
 for i, clave in enumerate(data):
    print(clave, ":", type(data[clave]))
    if i >= 10:
        break
# Out:
# Apple 1.png : <class 'str'>
# Apple 10.png : <class 'str'>
# Apple 100.png : <class 'str'>
# Apple 101.png : <class 'str'>
# Apple 102.png : <class 'str'>
# Apple 103.png : <class 'str'>
# Apple 104.png : <class 'str'>
# Apple 105.png : <class 'str'>
# Apple 106.png : <class 'str'>
# Apple 107.png : <class 'str'>
# Apple 108.png : <class 'str'>

# %%
print("Nº total de imágenes:", len(data))
# Out:
# Nº total de imágenes: 69687

# %%
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-8-2027567523.py in <cell line: 0>()
# ----> 1 print(data.head())
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
for i, (nombre, descripcion) in enumerate(data.items()):
    print(f"{nombre} → {descripcion}")
    if i >= 9:
        break
# Out:
# Apple 1.png → G80V76K49J80T71
# Apple 10.png → G80V76K49L46V78M
# Apple 100.png → G80V76K49L48J80T71
# Apple 101.png → G80V76K49L49J80T71
# Apple 102.png → G80V76K49L50J80T71
# Apple 103.png → G80V76K49L51J80T71
# Apple 104.png → G80V76K49L52J80T71
# Apple 105.png → G80V76K49L53J80T71
# Apple 106.png → G80V76K49L54J80T71
# Apple 107.png → G80V76K49L55J80T71
